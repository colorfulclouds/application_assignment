# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import matplotlib.pylab as pylab
import scipy.io

#import pygal

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# %matplotlib inline

# %% [markdown]
# # float of accuracy for 2 methods
# # sbp rms ar fc-ae cnn-ae rnn-ae

# %% [markdown]
# ## sbp

# %%
#accuracy
'''
base
'''
dt = np.array([[0.6423076923076925],
               [0.6294429708222813],
               [0.6610079575596817],
               [0.653315649867374]])
            
svm = np.array([[0.6545092838196285],
               [0.6629310344827586],
               [0.6894562334217506],
               [0.6677055702917772]])
                
nb = np.array([[0.1300397877984085],
               [0.13395225464190982],
               [0.1622679045092838],
               [0.11226790450928381]])

knn = np.array([[0.620026525198939],
               [0.6403846153846154],
               [0.6705570291777189],
               [0.6484084880636605]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''

dt = np.array([[0.7185676392572944 ],
               [0.7121352785145889 ],
               [0.7423740053050397 ],
               [0.721153846153846 ]])
                
svm = np.array([[0.5807029177718833 ],
               [0.5754641909814323 ],
               [0.5985411140583554 ],
               [0.5787135278514589 ]])
                
nb = np.array([[0.1130636604774536],
               [0.20384615384615384 ],
               [0.1142572944297082 ],
               [0.11246684350132626 ]])

knn = np.array([[0.6428381962864721 ],
               [0.6438992042440319 ],
               [0.6626657824933687 ],
               [0.6470159151193633 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3,fontsize=10.5)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('SBP',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## rms

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9872679045092839],
               [0.9895888594164457],
               [0.9912466843501324],
               [0.9929045092838195]])
                
svm =np.array([[0.17785145888594167],
               [0.1803050397877984],
               [0.1856763925729443],
               [0.1759946949602122]])
                
nb = np.array([[0.4370026525198939],
               [0.46803713527851454],
               [0.4938328912466843],
               [0.5543766578249336]])

knn =np.array([[0.9974801061007957],
               [0.9991379310344828],
               [0.9985411140583554],
               [0.9986737400530504]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''
dt = np.array([[0.997679045092838 ],
               [0.9992042440318303 ],
               [0.9993368700265253 ],
               [0.9987400530503978 ]])
                
svm = np.array([[0.8288461538461538  ],
               [0.969761273209549  ],
               [ 0.9998010610079575 ],
               [1.0]])
                
nb = np.array([[0.4342175066312997 ],
               [ 0.4639920424403184 ],
               [ 0.4913129973474802 ],
               [0.5571618037135279  ]])

knn = np.array([[ 0.9977453580901855 ],
               [ 0.9988726790450929 ],
               [0.9988063660477453  ],
               [0.9986074270557029  ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

'''
===========
'''

freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('RMS',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## ar

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9246684350132627],
               [0.9283819628647214],
               [0.9185676392572946],
               [0.9191644562334217]])
                
svm =np.array([[0.20251989389920425],
               [0.2055702917771883],
               [0.21220159151193635],
               [0.20305039787798407]])
                
nb = np.array([[0.4274535809018568],
               [0.5250000000000001],
               [0.6812997347480105],
               [0.7123342175066314 ]])

knn =np.array([[0.8330901856763926 ],
               [0.7886604774535809 ],
               [0.7748673740053051 ],
               [0.7797745358090185 ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''

dt = np.array([[0.9901193633952255 ],
               [0.990185676392573 ],
               [0.9841546846131154],
               [0.98536846064846]])
                
svm = np.array([[0.5262599469496021  ],
               [ 0.5954907161803714 ],
               [ 0.6648541114058356 ],
               [0.6460875331564988 ]])
                
nb = np.array([[0.43123342175066315 ],
               [0.5187665782493369  ],
               [0.7014588859416446  ],
               [ 0.7244031830238726 ]])

knn = np.array([[0.8258620689655173  ],
               [ 0.8049734748010611 ],
               [0.7876657824933686  ],
               [0.7871352785145888  ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

'''
===========
'''

freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('AR',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## fc-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9539787798408487 ],
               [0.961206896551724 ],
               [0.9739389920424403 ],
               [0.9783156498673738 ]])
                
svm =np.array([[0.9403846153846154 ],
               [0.7768567639257294 ],
               [0.8875994694960212 ],
               [0.9259283819628648 ]])
                
nb = np.array([[0.32526525198938994 ],
               [0.21551724137931033 ],
               [0.48322281167108744 ],
               [0.45722811671087527 ]])

knn =np.array([[0.9203580901856764 ],
               [0.9625331564986738 ],
               [0.9795755968169763 ],
               [0.9760610079575598 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''

dt = np.array([[0.9140583554376656  ],
               [0.9315646760231585 ],
               [0.9246548106468786],
               [0.9215643213406485 ]])
                
svm = np.array([[0.8240053050397878 ],
               [ 0.8401657824933687],
               [ 0.90004641909814323],
               [0.8442970822281168]])
                
nb = np.array([[0.3246684350132626],
               [ 0.4318302387267904 ],
               [ 0.46996021220159145 ],
               [ 0.481498673740053 ]])

knn = np.array([[0.8631962864721485  ],
               [ 0.4794429708222811 ],
               [ 0.974867374005305 ],
               [ 0.914257294429708]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

'''
===========
'''

freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('FC-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## cnn-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9255305039787798 ],
               [0.9414456233421751 ],
               [0.9431034482758621 ],
               [0.9391246684350133 ]])
                
svm =np.array([[0.19529177718832894 ],
               [0.18514588859416445 ],
               [0.17977453580901853 ],
               [0.17692307692307693 ]])
                
nb = np.array([[0.17990716180371352 ],
               [0.27970822281167107 ],
               [0.3797082228116711 ],
               [0.37234748010610075 ]])

knn =np.array([[0.9159814323607429 ],
               [0.9350795755968168 ],
               [0.9572281167108754 ],
               [0.9800397877984086 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''

dt = np.array([[0.9820291777188329 ],
               [0.9686339522546419 ],
               [0.9765915119363395 ],
               [0.9615384615384615 ]])
                
svm = np.array([[0.36644562334217506  ],
               [ 0.40271883289124666 ],
               [0.8592175066312997  ],
               [0.37586206896551727 ]])
                
nb = np.array([[0.3374005305039788 ],
               [ 0.32805039787798407 ],
               [0.24297082228116712  ],
               [ 0.28733421750663124 ]])

knn = np.array([[ 0.9447612732095492 ],
               [ 0.98289124668435 ],
               [0.9807692307692306  ],
               [0.9769893899204245  ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

'''
===========
'''
freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('CNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## rnn-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9190318302387268 ],
               [0.9305702917771883 ],
               [0.9771220159151193 ],
               [0.983554376657825 ]])
                
svm =np.array([[0.7598806366047746 ],
               [0.865318302387268 ],
               [0.9294429708222813 ],
               [0.9663793103448274 ]])
                
nb = np.array([[0.3114058355437666 ],
               [0.2696286472148541 ],
               [0.48249336870026516 ],
               [0.47155172413793095 ]])

knn =np.array([[0.9708885941644562 ],
               [0.9825596816976127 ],
               [0.9858753315649869 ],
               [0.9881962864721485 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_base = np.mean(tt , axis=1)

'''
bagging
'''

dt = np.array([[0.960344827586207 ],
               [0.9851458885941644 ],
               [0.9904509283819627 ],
               [0.9941644562334216 ]])
                
svm = np.array([[ 0.5910477453580901 ],
               [0.87446949602122  ],
               [ 0.9700928381962864 ],
               [0.9670424403183023 ]])
                
nb = np.array([[0.17407161803713528 ],
               [ 0.298342175066313 ],
               [0.3222148541114058  ],
               [ 0.28673740053050395 ]])

knn = np.array([[ 0.9656498673740053 ],
               [0.9584880636604775  ],
               [ 0.9761936339522546 ],
               [0.9807692307692311  ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_freq_bagging = np.mean(tt , axis=1)

'''
===========
'''
freq = ['决策树' , 'SVM' , '朴素贝叶斯' , 'kNN']
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_freq_base , marker='o' , label='Base')
plt.plot(freq , mean_freq_bagging , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('分类器',fontsize=10.5)

plt.xticks(freq)

plt.title('RNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# # float of variance for 2 methods
# # sbp rms ar fc-ae cnn-ae rnn-ae

# %% [markdown]
# ## sbp

# %%
'''
base
'''
dt = np.array([[0.00020845499511007578],
               [0.0003186190010483434],
               [0.0002749966579656507],
               [0.0004081503422946757]])
                
svm =np.array([[0.0001372476764066449],
               [0.00017664850241681882],
               [0.0002932679115451453],
               [0.0002698736711016049]])
                
nb = np.array([[0.0010123681655397562],
               [0.0003681514680325619],
               [0.0009715249878631384],
               [0.0011016884309324629]])

knn =np.array([[0.00023367855961837518],
               [0.0002640690851268917],
               [0.0003254789662911862],
               [0.00016532516235251042]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)

'''
bagging
'''

dt_b = np.array([[0.0003890127982325917],
                 [0.00018618209513892307],
                 [0.0005433224394739988],
                 [0.00020964669420033924]])
                
svm_b =np.array([[0.0005224611092739692],
                 [0.00029654398468996484],
                 [0.0003046704050545636],
                 [0.00038069412294464902]])
                
nb_b = np.array([[0.0002318096588310619],
                 [0.0005783654285895208],
                 [0.00023539794834270272],
                 [0.0002252364049560608]])

knn_b =np.array([[0.0002332564079111231],
                 [0.000234382145797128],
                 [0.00025861629224155456],
                 [0.0003256328757677887]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , base_variance_mean , marker='o' , label='Base')
plt.plot(freq , bagging_variance_mean , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('SBP',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %%
print(base_variance_mean)
print(bagging_variance_mean)

base_variance_mean - bagging_variance_mean
# Out:
# [0.00039794 0.00028187 0.00046632 0.00048626]
# [0.00034413 0.00032387 0.0003355  0.0002853 ]
# array([ 0.0000538 , -0.000042  ,  0.00013082,  0.00020096])

# %% [markdown]
# ## rms

# %%
'''
base
'''
dt = np.array([[1.590104763982012e-04],
               [1.798981910799342e-05],
               [1.6604633818573213e-05],
               [7.260129882008569e-06]])
                
svm =np.array([[0.00014421757698991768],
               [0.00011969320124675473],
               [0.00010272358209795329],
               [0.00010238937866304554]])
                
nb = np.array([[0.00021714428441767675],
               [0.0003120228806225329],
               [0.00024999736155182945],
               [0.0005686735289771967]])

knn =np.array([[1.6208585158553404e-06],
               [1.1037508179189347e-06],
               [1.2136861583491418e-06],
               [1.0553792681296804e-06]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)

'''
bagging
'''

dt_b = np.array([[1.67184037036777e-07],
                 [1.3016344306932585e-06],
                 [6.156379064089593e-07],
                 [2.370205939674529e-06]])
                
svm_b =np.array([[0.00022171319716595463],
                 [9.632094787129998e-06],
                 [4.001646391658366e-07],
                 [0.0]])
                
nb_b = np.array([[0.0002544167622371225],
                 [0.0003685516326717276],
                 [0.00016788885449134253],
                 [0.00030322805338811875]])

knn_b =np.array([[1.063210182299173e-06],
                 [2.1591300860486158e-06],
                 [1.3895827030374114e-06],
                 [1.6666197609214503e-06]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)
print(bagging_variance_mean.sum())

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , base_variance_mean , marker='o' , label='Base')
plt.plot(freq , bagging_variance_mean , marker='s' , label='Bagging')


#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('RMS',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()
# Out:
# 0.0003341409911066705

# %%
print(base_variance_mean)
print(bagging_variance_mean)

base_variance_mean - bagging_variance_mean
# Out:
# [0.0001305  0.0001127  0.00009263 0.00016984]
# [0.00011934 0.00009541 0.00004257 0.00007682]
# array([0.00001116, 0.00001729, 0.00005006, 0.00009303])

# %% [markdown]
# ## ar

# %%
'''
base
'''
dt = np.array([[8.418408628780898e-05],
               [9.375285831885107e-05],
               [7.412280393163955e-05],
               [0.00016806475103603094]])
                
svm =np.array([[0.00018347768576434096],
               [0.00015091923534254096],
               [0.00022303681866473412],
               [0.00013735761174707477]])
                
nb = np.array([[0.000477928501572515],
               [0.0003346035995468907],
               [0.0003080124394036406],
               [0.0003619774993140036]])

knn =np.array([[0.00020162581176255337],
               [8.553409226829166e-05],
               [0.00017024586819016561],
               [0.00017773906099388564]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)

'''
bagging
'''

dt_b = np.array([[1.6441929514736564e-05],
                 [7.458013494782964e-06],
                 [2.4516134502110254e-5],
                 [1.1230312461345845e-5]])
                
svm_b =np.array([[0.0002354438573408663],
                 [0.0002108035657747543],
                 [0.00021654623616573668],
                 [0.0002253718452954708]])
                
nb_b = np.array([[0.00044418714688768677],
                 [0.0003471773881473874],
                 [0.00022600947026996617],
                 [0.00038250462607912527]])

knn_b =np.array([[0.00020159502986723333],
                 [0.00010808402929732858],
                 [0.00014210681845365847],
                 [0.00013974980475483563]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , base_variance_mean , marker='o' , label='Base')
plt.plot(freq , bagging_variance_mean , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('AR',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %%
print(base_variance_mean)
print(bagging_variance_mean)

base_variance_mean - bagging_variance_mean
# Out:
# [0.0002368  0.0001662  0.00019385 0.00021128]
# [0.00022442 0.00016838 0.00015229 0.00018971]
# array([ 0.00001239, -0.00000218,  0.00004156,  0.00002157])

# %% [markdown]
# ## fc-ae

# %%
'''
base
'''
dt = np.array([[4.4343518915914265e-05],
               [3.3398356422686485e-05],
               [3.311692195118526e-05],
               [2.2387232725200382e-05]])
                
svm =np.array([[0.00010403840876949808],
               [0.0001384085936015872],
               [0.00012134662876682467],
               [8.606178190235633e-5]])
                
nb = np.array([[0.0002919662771144524],
               [0.00014150877020171815],
               [0.0005089170753329721],
               [0.00029601189764228255]])

knn =np.array([[9.524358153508419e-05],
               [5.3450562517149964e-05],
               [1.8187702720767773e-05],
               [3.315210126012283e-05]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)

'''
bagging
'''

dt_b = np.array([[0.00011039267144636205],
                 [0.00045130346516123456],
                 [0.00013543340313145468],
                 [0.00012130313546468461]])
                
svm_b =np.array([[0.0002701946822956609],
                 [0.00042378314770384645],
                 [0.00017992017814802034],
                 [0.00040955751465218205]])
                
nb_b = np.array([[0.00026412625150391535],
                 [0.00038422841221707045],
                 [0.00037945721844240114],
                 [0.00042188346502121274]])

knn_b =np.array([[0.0002195672593207578],
                 [0.0011671615222790563],
                 [2.6819825651344865e-05],
                 [5.70388520287909e-05]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , bagging_variance_mean , marker='o' , label='Base')
plt.plot(freq , base_variance_mean , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('FC-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %%
print(base_variance_mean)
print(bagging_variance_mean)

bagging_variance_mean -base_variance_mean
# Out:
# [0.0001339  0.00009169 0.00017039 0.0001094 ]
# [0.00021607 0.00060662 0.00018041 0.00025245]
# array([0.00008217, 0.00051493, 0.00001002, 0.00014304])

# %%
0.00051493 /0.00060662
# Out:
# 0.8488510105172926

# %%
0.00001002/0.00018041
# Out:
# 0.0555401585277978

# %% [markdown]
# ## cnn-ae

# %%
'''
base
'''
dt = np.array([[0.00010628988454150796],
               [8.166436828514954e-05],
               [5.574161501171469e-05],
               [7.684920037430798e-05]])
                
svm =np.array([[0.0002096466942003391],
               [0.00011282004376306032],
               [6.622065166151875e-05],
               [0.0001930288681409142]])
                
nb = np.array([[8.975560934081012e-05],
               [0.00018414609263415636],
               [0.00038030591927052163],
               [0.00025151007183614894]])

knn =np.array([[0.0001310912973425551],
               [9.928920206291466e-05],
               [3.287066678862143e-05],
               [2.5236756749150398e-05]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)
'''
bagging
'''

dt_b = np.array([[1.7849101872242838e-05],
                 [2.942309451273151e-05],
                 [3.329281849587352e-05],
                 [2.5856792069176453e-05]])
                
svm_b =np.array([[0.0003591983339079288],
                 [0.00029748942861766427],
                 [0.00013425743514694375],
                 [0.00041782465225253114]])
                
nb_b = np.array([[0.00023665121122360688],
                 [0.0003578219434457431],
                 [0.0005781015837724884],
                 [0.0001833325711149729]])

knn_b =np.array([[6.759264471008715e-05],
                 [1.000851339276293e-05],
                 [1.9964257822119283e-05],
                 [4.45501973559232e-05]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , bagging_variance_mean , marker='o' , label='Base')
plt.plot(freq , base_variance_mean , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('CNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %%
print(base_variance_mean)
print(bagging_variance_mean)

bagging_variance_mean-base_variance_mean
# Out:
# [0.0001342  0.00011948 0.00013378 0.00013666]
# [0.00017032 0.00017369 0.0001914  0.00016789]
# array([0.00003613, 0.00005421, 0.00005762, 0.00003123])

# %% [markdown]
# ## rnn-ae

# %%
'''
base
'''
dt = np.array([[0.00010315892604605709],
               [7.304543759542392e-05],
               [3.058401170767403e-05],
               [1.678053036326164e-05]])
                
svm =np.array([[0.00025671660955892166],
               [ 9.911330551822645e-05],
               [6.149343202302153e-05],
               [4.929940406250664e-05]])
                
nb = np.array([[0.0003063414222291017],
               [0.0005438897058306187],
               [0.00010318091311414284],
               [0.0003119481245910403]])

knn =np.array([[3.4383377072940864e-05],
               [1.306471585672166e-05],
               [1.1129853865150585e-05],
               [ 1.1767478839645619e-05]])

tt = np.array([dt , svm , nb , knn]).squeeze()
base_variance_mean = np.mean(tt , axis=0)
'''
bagging
'''

dt_b = np.array([[3.164378838942089e-05],
                 [1.751929585095231e-05],
                 [1.6463916582822595e-05],
                 [8.689289307600762e-06]])
                
svm_b =np.array([[0.00026758701602065725],
                 [0.00028763922211512096],
                 [2.646803256196828e-05],
                 [3.45240943086914e-05]])
                
nb_b = np.array([[0.00011782869787305895],
                 [0.0002271659900512914],
                 [0.00032179833109358385],
                 [0.0002679052128699982]])

knn_b =np.array([[5.521392537764986e-05],
                 [4.663017399686189e-05],
                 [4.2474618128601554e-05],
                 [1.6446326928353846e-05]])

tt = np.array([dt_b , svm_b , nb_b , knn_b]).squeeze()
bagging_variance_mean = np.mean(tt , axis=0)

print(bagging_variance_mean.sum())

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.35,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , base_variance_mean , marker='o' , label='Base')
plt.plot(freq , bagging_variance_mean , marker='s' , label='Bagging')

#plt.legend(loc=3)
plt.ylabel('方差',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('RNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()
# Out:
# 0.0004464994828641585

# %%
print(base_variance_mean)
print(bagging_variance_mean)

base_variance_mean - bagging_variance_mean
# Out:
# [0.00017515 0.00018228 0.0000516  0.00009745]
# [0.00011807 0.00014474 0.0001018  0.00008189]
# array([ 0.00005708,  0.00003754, -0.0000502 ,  0.00001556])

# %%
np.set_printoptions(suppress=True)
