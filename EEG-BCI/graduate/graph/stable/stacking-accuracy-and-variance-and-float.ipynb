# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import matplotlib.pylab as pylab
import scipy.io

#import pygal

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# %matplotlib inline

# %% [markdown]
# # accuracy
# # sbp rms ar fc-ae cnn-ae rnn-ae
# # stacking的准确率一幅图可以画完

# %%
#accuracy
sbp = np.array([[0.6821618037135277  ],
               [ 0.6860079575596817 ],
               [ 0.7141246684350133 ],
               [0.6972148541114059]])
                
rms = np.array([[0.998076923076923  ],
               [0.9991379310344828 ],
               [0.9998010610079575 ],
               [0.9999336870026525 ]])
                
ar = np.array([[0.9586870026525199 ],
               [0.962997347480106 ],
               [0.9639257294429706 ],
               [0.9624005305039788 ]])

fc_ae = np.array([[0.9458222811671086],
               [0.9616710875331564 ],
               [0.9688328912466841 ],
               [0.9363395225464191 ]])

cnn_ae = np.array([[0.9076259946949603 ],
                   [0.9864721485411142 ],
                   [0.9775198938992042 ],
                   [0.983023872679045 ]])

rnn_ae = np.array([[0.9718832891246686 ],
                   [0.9838859416445624 ],
                   [0.987997347480106 ],
                   [0.9881962864721485 ]])

sbp = sbp * 100
rms = rms * 100
ar = ar * 100
fc_ae = fc_ae * 100
cnn_ae = cnn_ae * 100
rnn_ae = rnn_ae * 100

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.8,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , sbp , marker='o' , label='SBP')
plt.plot(freq , rms , marker='s' , label='RMS')
plt.plot(freq , ar , marker='p' , label='AR')
plt.plot(freq , fc_ae , marker='d' , label='FC-AE')
plt.plot(freq , cnn_ae , marker='*' , label='CNN-AE')
plt.plot(freq , rnn_ae , marker='x' , label='RNN-AE')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('Stacking',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# # float of accuracy for three methods
# # sbp rms  ar fc-ae cnn-ae rnn-ae

# %% [markdown]
# ## sbp

# %%
#accuracy
'''
base
'''
dt = np.array([[0.6423076923076925],
               [0.6294429708222813],
               [0.6610079575596817],
               [0.653315649867374]])
            
svm = np.array([[0.6545092838196285],
               [0.6629310344827586],
               [0.6894562334217506],
               [0.6677055702917772]])
                
nb = np.array([[0.1300397877984085],
               [0.13395225464190982],
               [0.1622679045092838],
               [0.11226790450928381]])

knn = np.array([[0.620026525198939],
               [0.6403846153846154],
               [0.6705570291777189],
               [0.6484084880636605]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''

dt = np.array([[0.7185676392572944 ],
               [0.7121352785145889 ],
               [0.7423740053050397 ],
               [0.721153846153846 ]])
                
svm = np.array([[0.5807029177718833 ],
               [0.5754641909814323 ],
               [0.5985411140583554 ],
               [0.5787135278514589 ]])
                
nb = np.array([[0.1130636604774536],
               [0.20384615384615384 ],
               [0.1142572944297082 ],
               [0.11246684350132626 ]])

knn = np.array([[0.6428381962864721 ],
               [0.6438992042440319 ],
               [0.6626657824933687 ],
               [0.6470159151193633 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''

sbp_s = np.array([[0.6821618037135277  ],
               [ 0.6860079575596817 ],
               [ 0.7141246684350133 ],
               [0.6972148541114059]])



sbp_s = sbp_s * 100

'''
=============
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , sbp_s , marker='*' , label='Stacking')

#plt.legend(loc=0)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('SBP',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## rms

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9872679045092839],
               [0.9895888594164457],
               [0.9912466843501324],
               [0.9929045092838195]])
                
svm =np.array([[0.17785145888594167],
               [0.1803050397877984],
               [0.1856763925729443],
               [0.1759946949602122]])
                
nb = np.array([[0.4370026525198939],
               [0.46803713527851454],
               [0.4938328912466843],
               [0.5543766578249336]])

knn =np.array([[0.9974801061007957],
               [0.9991379310344828],
               [0.9985411140583554],
               [0.9986737400530504]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''
dt = np.array([[0.997679045092838 ],
               [0.9992042440318303 ],
               [0.9993368700265253 ],
               [0.9987400530503978 ]])
                
svm = np.array([[0.8288461538461538  ],
               [0.969761273209549  ],
               [ 0.9998010610079575 ],
               [1.0]])
                
nb = np.array([[0.4342175066312997 ],
               [ 0.4639920424403184 ],
               [ 0.4913129973474802 ],
               [0.5571618037135279  ]])

knn = np.array([[ 0.9977453580901855 ],
               [ 0.9988726790450929 ],
               [0.9988063660477453  ],
               [0.9986074270557029  ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''
rms_s = np.array([[0.998076923076923  ],
               [0.9991379310344828 ],
               [0.9998010610079575 ],
               [0.9999336870026525 ]])

rms_s *= 100
'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , rms_s , marker='*' , label='Stacking')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('RMS',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## ar

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9246684350132627],
               [0.9283819628647214],
               [0.9185676392572946],
               [0.9191644562334217]])
                
svm =np.array([[0.20251989389920425],
               [0.2055702917771883],
               [0.21220159151193635],
               [0.20305039787798407]])
                
nb = np.array([[0.4274535809018568],
               [0.5250000000000001],
               [0.6812997347480105],
               [0.7123342175066314 ]])

knn =np.array([[0.8330901856763926 ],
               [0.7886604774535809 ],
               [0.7748673740053051 ],
               [0.7797745358090185 ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''

dt = np.array([[0.9901193633952255 ],
               [0.990185676392573 ],
               [0.9841546846131154],
               [0.98536846064846]])
                
svm = np.array([[0.5262599469496021  ],
               [ 0.5954907161803714 ],
               [ 0.6648541114058356 ],
               [0.6460875331564988 ]])
                
nb = np.array([[0.43123342175066315 ],
               [0.5187665782493369  ],
               [0.7014588859416446  ],
               [ 0.7244031830238726 ]])

knn = np.array([[0.8258620689655173  ],
               [ 0.8049734748010611 ],
               [0.7876657824933686  ],
               [0.7871352785145888  ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''
ar_s = np.array([[0.9586870026525199 ],
               [0.962997347480106 ],
               [0.9639257294429706 ],
               [0.9624005305039788 ]])

ar_s *= 100
'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , ar_s , marker='*' , label='Stacking')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('AR',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## fc-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9539787798408487 ],
               [0.961206896551724 ],
               [0.9739389920424403 ],
               [0.9783156498673738 ]])
                
svm =np.array([[0.9403846153846154 ],
               [0.7768567639257294 ],
               [0.8875994694960212 ],
               [0.9259283819628648 ]])
                
nb = np.array([[0.32526525198938994 ],
               [0.21551724137931033 ],
               [0.48322281167108744 ],
               [0.45722811671087527 ]])

knn =np.array([[0.9203580901856764 ],
               [0.9625331564986738 ],
               [0.9795755968169763 ],
               [0.9760610079575598 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''

dt = np.array([[0.9140583554376656  ],
               [0.9315646760231585 ],
               [0.9246548106468786],
               [0.9215643213406485 ]])
                
svm = np.array([[0.3240053050397878 ],
               [ 0.401657824933687],
               [ 0.6004641909814323],
               [0.5442970822281168]])
                
nb = np.array([[0.3246684350132626],
               [ 0.4318302387267904 ],
               [ 0.46996021220159145 ],
               [ 0.481498673740053 ]])

knn = np.array([[0.8631962864721485  ],
               [ 0.4794429708222811 ],
               [ 0.974867374005305 ],
               [ 0.914257294429708]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''
fc_ae_s = np.array([[0.9458222811671086],
               [0.9616710875331564 ],
               [0.9688328912466841 ],
               [0.9363395225464191 ]])

fc_ae_s *= 100
'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , fc_ae_s , marker='*' , label='Stacking')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('FC-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## cnn-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9255305039787798 ],
               [0.9414456233421751 ],
               [0.9431034482758621 ],
               [0.9391246684350133 ]])
                
svm =np.array([[0.19529177718832894 ],
               [0.18514588859416445 ],
               [0.17977453580901853 ],
               [0.17692307692307693 ]])
                
nb = np.array([[0.17990716180371352 ],
               [0.27970822281167107 ],
               [0.3797082228116711 ],
               [0.37234748010610075 ]])

knn =np.array([[0.9159814323607429 ],
               [0.9350795755968168 ],
               [0.9572281167108754 ],
               [0.9800397877984086 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''

dt = np.array([[0.9820291777188329 ],
               [0.9686339522546419 ],
               [0.9765915119363395 ],
               [0.9615384615384615 ]])
                
svm = np.array([[0.36644562334217506  ],
               [ 0.40271883289124666 ],
               [0.8592175066312997  ],
               [0.37586206896551727 ]])
                
nb = np.array([[0.3374005305039788 ],
               [ 0.32805039787798407 ],
               [0.24297082228116712  ],
               [ 0.28733421750663124 ]])

knn = np.array([[ 0.9447612732095492 ],
               [ 0.98289124668435 ],
               [0.9807692307692306  ],
               [0.9769893899204245  ]])


dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''
cnn_ae_s = np.array([[0.9076259946949603 ],
                   [0.9864721485411142 ],
                   [0.9775198938992042 ],
                   [0.983023872679045 ]])
cnn_ae_s *= 100

'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , cnn_ae_s , marker='*' , label='Stacking')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('CNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()

# %% [markdown]
# ## rnn-ae

# %%
#accuracy
'''
base
'''
dt = np.array([[0.9190318302387268 ],
               [0.9305702917771883 ],
               [0.9771220159151193 ],
               [0.983554376657825 ]])
                
svm =np.array([[0.7598806366047746 ],
               [0.865318302387268 ],
               [0.9294429708222813 ],
               [0.9663793103448274 ]])
                
nb = np.array([[0.3114058355437666 ],
               [0.2696286472148541 ],
               [0.48249336870026516 ],
               [0.47155172413793095 ]])

knn =np.array([[0.9708885941644562 ],
               [0.9825596816976127 ],
               [0.9858753315649869 ],
               [0.9881962864721485 ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_base = np.mean(tt , axis=0)

'''
bagging
'''

dt = np.array([[0.960344827586207 ],
               [0.9851458885941644 ],
               [0.9904509283819627 ],
               [0.9941644562334216 ]])
                
svm = np.array([[ 0.5910477453580901 ],
               [0.87446949602122  ],
               [ 0.9700928381962864 ],
               [0.9670424403183023 ]])
                
nb = np.array([[0.17407161803713528 ],
               [ 0.298342175066313 ],
               [0.3222148541114058  ],
               [ 0.28673740053050395 ]])

knn = np.array([[ 0.9656498673740053 ],
               [0.9584880636604775  ],
               [ 0.9761936339522546 ],
               [0.9807692307692311  ]])

dt = dt * 100
svm = svm * 100
nb = nb * 100
knn = knn * 100

tt = np.array( [dt , svm , nb , knn] )
tt = np.squeeze(tt)
mean_method_bagging = np.mean(tt , axis=0)

'''
stacking
'''
rnn_ae_s = np.array([[0.9718832891246686 ],
                   [0.9838859416445624 ],
                   [0.987997347480106 ],
                   [0.9881962864721485 ]])

rnn_ae_s *= 100
'''
===========
'''

freq = [6 , 7.5 , 8.5 , 10]
plt.figure(figsize=(2.4,2.0) , dpi=100) #2.2,2.0) , dpi=115

plt.plot(freq , mean_method_base , marker='o' , label='Base')
plt.plot(freq , mean_method_bagging , marker='s' , label='Bagging')
plt.plot(freq , rnn_ae_s , marker='*' , label='Stacking')

#plt.legend(loc=3)
plt.ylabel('准确率(%)',fontsize=10.5)
plt.xlabel('刺激频率(Hz)',fontsize=10.5)

plt.xticks(freq)

plt.title('RNN-AE',fontsize=10.5)

plt.grid() #去掉网格线
plt.show()
plt.close()
