freq_ar = np.array([freq_6 , freq_75 , freq_85 , freq_10])
freq_ar = np.mean(freq_ar , axis=0)
freq_ar *= 100

# cnn
freq_6 =  np.array([0.48888888888888893, 0.5573671497584541, 0.586231884057971, 0.827536231884058, 0.7423913043478259, 0.8176328502415459, 0.8446859903381642, 0.85990821256038648, 0.8670289855072464])
freq_75 = np.array([0.585144927536232, 0.6060386473429952, 0.5720772946859904, 0.682487922705314, 0.7617149758454107, 0.7955314009661835, 0.7924637681159419, 0.8360628019323674, 0.9033091787439613])
freq_85 = np.array([0.5682367149758455, 0.5341787439613526, 0.5931159420289855, 0.6409420289855072, 0.7832125603864736, 0.8087681159420289, 0.8253623188405795, 0.8219806763285022, 0.8445652173913043])
freq_10 = np.array([0.4471014492753624, 0.5766908212560387, 0.6085748792270531, 0.685144927536232, 0.75475845410628, 0.785144927536232, 0.8195169082125605, 0.8747584541062802, 0.8651851851851853])

freq_cnn = np.array([freq_6 , freq_75 , freq_85 , freq_10])
freq_cnn = np.mean(freq_cnn , axis=0)
freq_cnn *= 100

# rnn
freq_6 =  np.array([0.59323671497584537, 0.6111111111111112, 0.65347826086956526, 0.7395893719806763, 0.7771014492753624, 0.8154589371980676, 0.845048309178744, 0.9171497584541063, 0.906304347826087])
freq_75 = np.array([0.5327294685990339, 0.6022946859903382, 0.6205072463768116, 0.7423671497584541, 0.7646135265700483, 0.8002415458937198, 0.8537922705314008, 0.9067874396135266, 0.9251207729468599])
freq_85 = np.array([0.5672705314009662, 0.60864734299516905, 0.6340821256038646, 0.7226328502415457, 0.7793478260869565, 0.8413043478260869, 0.8358454106280192, 0.9045169082125605, 0.91457729468599034])
freq_10 = np.array([0.54637681159420284, 0.6158454106280194, 0.6453381642512078, 0.7514251207729467, 0.7830676328502415, 0.8285024154589372, 1.0, 0.8728260869565218, 0.928395061728395])

freq_rnn = np.array([freq_6 , freq_75 , freq_85 , freq_10])
freq_rnn = np.mean(freq_rnn , axis=0)
freq_rnn *= 100


'''
============
'''

session = [1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , 9]

plt.plot(session , freq_sbp , marker='o' , label='sbp')
plt.plot(session , freq_rms , marker='s' , label='rms')
plt.plot(session , freq_ar , marker='x' , label='ar')
plt.plot(session , freq_cnn , marker='*' , label='cnn')
plt.plot(session , freq_rnn , marker='d' , label='rnn')


plt.legend(loc=3)
plt.ylabel('Accuracy(%)')
plt.xlabel('Session')

plt.xticks(session)

plt.title('Naive Bayes')

plt.grid() #去掉网格线
plt.show()
plt.close()
