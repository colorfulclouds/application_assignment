# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

# %%
test = pd.read_csv('sbp_mfcc_ar_different_freq.csv')
test.iloc[:,0] =(1 - test.iloc[:,0])*100

# %%
test.iloc[:,:]
# Out:
#     Accuracy(%) Session Method
# 0     46.376811      s1    SBP
# 1     79.227053      s2    SBP
# 2     47.101449      s3    SBP
# 3     60.628019      s4    SBP
# 4     87.922705      s5    SBP
# 5     82.367150      s6    SBP
# 6     54.347826      s7    SBP
# 7     92.028986      s8    SBP
# 8     86.714976      s9    SBP
# 9     75.362319     s10    SBP
# 10    34.299517      s1    SBP
# 11    76.570048      s2    SBP
# 12    90.821256      s3    SBP
# 13    60.144928      s4    SBP
# 14    66.183575      s5    SBP
# 15    71.980676      s6    SBP
# 16    67.874396      s7    SBP
# 17    80.917874      s8    SBP
# 18    92.512077      s9    SBP
# 19    61.835749     s10    SBP
# 20    57.246377      s1    SBP
# 21    61.594203      s2    SBP
# 22    43.236715      s3    SBP
# 23    57.487923      s4    SBP
# 24    69.082126      s5    SBP
# 25    77.536232      s6    SBP
# 26    71.980676      s7    SBP
# 27    92.028986      s8    SBP
# 28    76.086956      s9    SBP
# ...

# %%
sns.set(style="whitegrid")
g=sns.catplot(x='Session' , y='Accuracy(%)' , hue='Method' ,capsize=.2, palette="YlGnBu_d", height=6, aspect=.75, kind='point' , data=test)
g.despine(left=True)
