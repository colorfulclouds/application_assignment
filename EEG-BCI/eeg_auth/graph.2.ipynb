# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
sns.set(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
planets = sns.load_dataset("planets")

# %%
# Plot the orbital period with horizontal boxes
sns.boxplot(x="distance", y="method", data=planets,
            whis="range", palette="vlag")

# Add in points to show each observation
sns.swarmplot(x="distance", y="method", data=planets,
              size=2, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.set(style="darkgrid")

tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "total_bill", color="steelblue", bins=bins)

# %%
import numpy as np
import matplotlib.pyplot as plt
size = 4
a = np.array([0.009070,0.003742,0.002213,0.002790]) #SBP
b = np.array([0.024598,0.003385,0.014218,0.002304]) #DWT
c = np.array([0.008755,0.006533,0.005246,0.009112]) #RMS
#d = np.array([0.8578,0.8159,0.8002,0.8387])
#           ['lgbm' , 'xgb' , 'gbc' ,'rf' ,'knn' ,'svc','dt' ,'lda'  ,'mlp' , 'nb' ,'ada']

x = np.arange(size)

total_width, n = 0.8, 3     # 有多少个类型，只需更改n即可
width = total_width / n
#x = x - (total_width - width) / 2
fig, ax = plt.subplots()
plt.bar(x, a,  width=width,             label='SBP' ,            color='#B0E0E6', edgecolor = 'black')
plt.bar(x + width, b, width=width,     label= 'DWT' ,     color='#87CEEB', edgecolor = 'black')
plt.bar(x + 2 * width, c, width=width, label= 'RMS' , color='#4169E1', edgecolor = 'black')
#plt.bar(x + 3 * width, d, width=width, label='25hz' , color='#6A5ACD', edgecolor = 'black')

#ax.set_xticklabels(freq)

plt.ylabel('Variance_bagging')
plt.xlabel('Freq(Hz)')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
size = 4
a = np.array([0.007734,0.003261,0.003788,0.003317]) #SBP
b = np.array([0.019726,0.011053,0.022386,0.006685]) #DWT
c = np.array([0.010970,0.005284,0.011022,0.006459]) #RMS
#d = np.array([0.8578,0.8159,0.8002,0.8387])
#           ['lgbm' , 'xgb' , 'gbc' ,'rf' ,'knn' ,'svc','dt' ,'lda'  ,'mlp' , 'nb' ,'ada']

x = np.arange(size)

total_width, n = 0.8, 3     # 有多少个类型，只需更改n即可
width = total_width / n
#x = x - (total_width - width) / 2
fig, ax = plt.subplots()
plt.bar(x, a,  width=width,             label='SBP' ,            color='#B0E0E6', edgecolor = 'black')
plt.bar(x + width, b, width=width,     label= 'DWT' ,     color='#87CEEB', edgecolor = 'black')
plt.bar(x + 2 * width, c, width=width, label= 'RMS' , color='#4169E1', edgecolor = 'black')
#plt.bar(x + 3 * width, d, width=width, label='25hz' , color='#6A5ACD', edgecolor = 'black')

#ax.set_xticklabels(freq)

plt.ylabel('Variance_stacking')
plt.xlabel('Freq(Hz)')

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
size = 4
a = np.array([0.004678,0.002784,0.003462,0.004603]) #SBP
b = np.array([0.015831,0.005231,0.043700,0.009280]) #DWT
c = np.array([0.009111,0.005329,0.004638,0.007628]) #RMS
#d = np.array([0.8578,0.8159,0.8002,0.8387])
#           ['lgbm' , 'xgb' , 'gbc' ,'rf' ,'knn' ,'svc','dt' ,'lda'  ,'mlp' , 'nb' ,'ada']

x = np.arange(size)

total_width, n = 0.8, 3     # 有多少个类型，只需更改n即可
width = total_width / n
#x = x - (total_width - width) / 2
fig, ax = plt.subplots()
plt.bar(x, a,  width=width,             label='SBP' ,            color='#B0E0E6', edgecolor = 'black')
plt.bar(x + width, b, width=width,     label= 'DWT' ,     color='#87CEEB', edgecolor = 'black')
plt.bar(x + 2 * width, c, width=width, label= 'RMS' , color='#4169E1', edgecolor = 'black')
#plt.bar(x + 3 * width, d, width=width, label='25hz' , color='#6A5ACD', edgecolor = 'black')

#ax.set_xticklabels(freq)

plt.ylabel('Variance_voting')
plt.xlabel('Freq(Hz)')

plt.legend()
plt.show()
