# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "I:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "I:\Anaconda3\lib\site-packages\nltk\downloader.py", line 1577, in _download
#     return self._download_threaded(*e)
#   File "I:\Anaconda3\lib\site-packages\nltk\downloader.py", line 1840, in _download_threaded
#     assert self._download_msg_queue == []
# AssertionError
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "I:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "I:\Anaconda3\lib\site-packages\nltk\downloader.py", line 1577, in _download
#     return self._download_threaded(*e)
#   File "I:\Anaconda3\lib\site-packages\nltk\downloader.py", line 1840, in _download_threaded
#     assert self._download_msg_queue == []
# AssertionError
# ...

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.concordance('kiss')
#查词
# Out:
# Displaying 2 of 2 matches:
#  it ' s the resurrection ; they must kiss their last , and come to judgment .
#  form of love , and I will kneel and kiss thee ; but at thy highest , come as

# %%
text1.concordance('hate')
# Out:
# Displaying 9 of 9 matches:
#  inscrutable thing is chiefly what I hate ; and be the white whale agent , or
#  whale principal , I will wreak that hate upon him . Talk not to me of blasphe
# bey , rebelling ; and worse yet , to hate with touch of pity ! For in his eyes
#  the sum of all the general rage and hate felt by his whole race from Adam dow
# s were possessed , that at times his hate seemed almost theirs ; the White Wha
# thout being mad ? Do the heavens yet hate thee , that thou can ' st not go mad
# e wilt thou be kind ; and e ' en for hate thou canst but kill ; and all are ki
# royal rights . But war is pain , and hate is woe . Come in thy lowest form of
#  hell ' s heart I stab at thee ; for hate ' s sake I spit my last breath at th

# %%
text1.similar('monstrous')
#上下文词
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar('monstrous')
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.similar('love')
# Out:
# affection sister heart mother time see town life it dear elinor
# marianne me word family her him do regard head

# %%
text2.common_contexts(['monstrous' , 'very'])
#多个词的上下文
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text2.similar('like')
# Out:
# see and to saw think in for that have come know wish meet tell engage
# not gave be much give

# %%
text4.dispersion_plot(['citizens','democracy' , 'freedom','duties' , 'America'])
#下图每一行代表整个文本
#每一个竖线代表一个单词

# %%
len(text3)
#文章长度
# Out:
# 44764

# %%
len(set(text3))
#文章的不同词汇数量
# Out:
# 2789

# %%
len(text3)/len(set(text3))
#每一个单词平均出现16次
# Out:
# 16.050197203298673

# %%
text3.count('smote')
#统计指定词的出现次数
# Out:
# 5

# %%
text4.count('love')/len(text4)
#指定词的出现百分比
# Out:
# 0.000336226712869249

# %%
text5.count('lol')
# Out:
# 704

# %%
text5.count('lol')/len(text5)
# Out:
# 0.015640968673628082

# %%
def lexical_diversity(text):
    return len(text)/len(set(text))
#每个词出现的百分比

def percentage(count , total):
    return 100*count/total

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
sent1
# Out:
# ['Call', 'me', 'Ishmael', '.']

# %%
sent2
# Out:
# ['The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.']

# %%
fei=['love','this','that','that']

fei.count('that')
# Out:
# 2

# %%
fei.index('that') #返回第一个指定元素的索引值
# Out:
# 2

# %%
fei[6]='f'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-52af1923ef70> in <module>()
# ----> 1 fei[6]='f'
#
# IndexError: list assignment index out of range

# %%
fei[0:4]=['haha','hoho']

# %%
fei
# Out:
# ['haha', 'hoho']

# %%
sorted
# Out:
# <function sorted>

# %%
name = 'alice'

# %%
name*2
# Out:
# 'alicealice'

# %%
name+'g'
# Out:
# 'aliceg'

# %%
name.join(['is','nice'])
# Out:
# 'isalicenice'

# %%
' '.join(['hello','world'])
# Out:
# 'hello world'

# %%
'hello world'.split()
# Out:
# ['hello', 'world']

# %%
swim=['he','is','doing']

swim[-2:]
# Out:
# ['is', 'doing']

# %%
#使用函数来寻找每个词的出现次数
#用来寻找最常见的词

fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({'[': 3,
#           'Moby': 84,
#           'Dick': 84,
#           'by': 1137,
#           'Herman': 1,
#           'Melville': 1,
#           '1851': 3,
#           ']': 1,
#           'ETYMOLOGY': 1,
#           '.': 6862,
#           '(': 210,
#           'Supplied': 2,
#           'a': 4569,
#           'Late': 1,
#           'Consumptive': 1,
#           'Usher': 2,
#           'to': 4542,
#           'Grammar': 2,
#           'School': 1,
#           ')': 78,
#           'The': 612,
#           'pale': 18,
#           '--': 1070,
#           'threadbare': 1,
#           'in': 3916,
#           'coat': 28,
#           ',': 18713,
#           'heart': 90,
#           'body': 110,
#           'and': 6024,
#           'brain': 37,
#           ';': 4072,
#           'I': 2124,
#           'see': 253,
#           'him': 1058,
#           'now': 646,
#           'He': 230,
#           'was': 1632,
#           'ever': 203,
#           'dusting': 2,
#           'his': 2459,
# ...

# %%
vocabulary1 = fdist1.keys()

#vocabulary1[:50]

# %%
fdist1['whale']
# Out:
# 906

# %%
len(text1)
# Out:
# 260819

# %%
fdist1.plot(50 , cumulative=False)

# %%
fdist1.plot(50 , cumulative=True)
#累计频率

# %%
fdist1.hapaxes()
#返回只出现一次的词
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
V = set(text1)

long_words = [w for w in V if len(w)>15]

sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
fdist5 = FreqDist(text5)

sorted([w for w in set(text5) if len(w)>7 and fdist5[w]>7])
#长度超过7 出现次数超过7
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %%
from nltk import bigrams

# %%
list(bigrams(['hello','world','boy','and','girl']))
#自己构造双连词
# Out:
# [('hello', 'world'), ('world', 'boy'), ('boy', 'and'), ('and', 'girl')]

# %%
#双连词 经常一起出现的两个词
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
# ...

# %%
fdist = FreqDist([len(w) for w in text1])

# %%
fdist
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
fdist.keys()
# Out:
# dict_keys([1, 4, 2, 6, 8, 9, 11, 5, 7, 3, 10, 12, 13, 14, 16, 15, 17, 18, 20])

# %%
len(fdist)
# Out:
# 19

# %%
fdist.items()
# Out:
# dict_items([(1, 47933), (4, 42345), (2, 38513), (6, 17111), (8, 9966), (9, 6428), (11, 1873), (5, 26597), (7, 14399), (3, 50223), (10, 3528), (12, 1053), (13, 567), (14, 177), (16, 22), (15, 70), (17, 12), (18, 1), (20, 1)])

# %%
fdist.max()
# Out:
# 3

# %%
fdist[3]
# Out:
# 50223

# %%
fdist.freq(3) #长度为3 的词的百分比
# Out:
# 0.19255882431878046

# %%
s='12'
s.isdigit()
# Out:
# True

# %%
babelize_shell()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-5e984664ba12> in <module>()
# ----> 1 babelize_shell()
#
# NameError: name 'babelize_shell' is not defined
